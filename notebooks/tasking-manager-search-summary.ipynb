# %% [markdown]
# This is a Jupyter notebook for quickly summarizing the status of a HOTOSM Tasking Manager campaing using the TM API.
# It uses the same search functionality as the keyword search o tasks.atotosm.org/contribute
#
# **Usage**:
#
# 1. Set your search keydword to `textSearch`
# 2. Execute all cells.
# 3. The results are sorted by project ID by default so the order stays consistent over time

# %%
# set the text search keyword
textSearch = 'COVID'
sort_by = 'projectId'

#################
import requests
import json
import pandas as pd

def getAllPages(textSearch):
    page = 1
    while True:
        r = requests.get(f'https://tasks.hotosm.org/api/v1/project/search?mapperLevel=ALL&textSearch={textSearch}&page={page}', 
            headers = {
                'Accept-Language': '*'
            }
        )
        j = json.loads(r.content)
        df = pd.DataFrame(json.loads(r.content)['results'])
        yield df
        if j['pagination']['hasNext'] is True:
            page = j['pagination']['nextNum']
        else:
            break

res = pd.concat(getAllPages(textSearch), ignore_index=True);

pd.set_option('display.max_rows', 500)
display(res[['projectId','name','percentMapped', 'percentValidated','priority','status']].sort_values(sort_by))
# Out:
#     projectId                                            name  percentMapped  \
# 39       5909              COVID-19, Quehue, Anna, Cusco Peru             98
# 38       7372           COVID-19 - Paucartambo 1, Cusco, Peru             99
# 29       7379       COVID-19 Yaurisque District, Cusco - Peru            100
# 37       7721                   COVID-19 - Coya - Calca, Peru            100
# 28       7768         COVID-19 - Chamaca - Chumbivilcas, Peru             53
# 36       7769                COVID-19 - Saylla - Cusco , Peru            100
# 4        7770            COVID-19 San Jeronimo - Cusco , Peru             94
# 27       7968  COVID-19 - Andahuaylillas - Quispicanchi, Peru             99
# 35       7970             COVID-19 Lucre - Quispicanchi, Peru             92
# 26       7972           COVID-19 - Urcos - Quispicanchi, Peru             99
# 25       8047    COVID-19 - Santa Teresa, La Convención, Peru             74
# 34       8048                 COVID-19 - Ccapi - Paruro, Peru             99
# 24       8049                  COVID-19 Omacha - Paruro, Peru             99
# 33       8159                                        Impendle             26
# 8        8188            Mapatón COVID-19 Medellín - Comuna 1             59
# 7        8189            Mapatón COVID-19 Medellín - Comuna 2             25
# 23       8190            Mapatón COVID-19 Medellín - Comuna 3             15
# 22       8191            Mapatón COVID-19 Medellín - Comuna 4              1
# 21       8192            Mapatón COVID-19 Medellín - Comuna 5             17
# 20       8193            Mapatón COVID-19 Medellín - Comuna 6              4
# 19       8194            Mapatón COVID-19 Medellín - Comuna 7             13
# 18       8195            Mapatón COVID-19 Medellín - Comuna 8              2
# 17       8196            Mapatón COVID-19 Medellín - Comuna 9              5
# 16       8197           Mapatón COVID-19 Medellín - Comuna 10             12
# 15       8198           Mapatón COVID-19 Medellín - Comuna 11             18
# 14       8199           Mapatón COVID-19 Medellín - Comuna 12              3
# 13       8200           Mapatón COVID-19 Medellín - Comuna 13              2
# 12       8201           Mapatón COVID-19 Medellín - Comuna 14             28
# 11       8202           Mapatón COVID-19 Medellín - Comuna 16             40
# 10       8203           Mapatón COVID-19 Medellín - Comuna 15             42
# 3        8213                COVID-19 - Urubamba, Cusco, Peru             85
# 2        8214                    COVID-19 - Anta, Cusco, Peru             94
# 6        8216                 COVID-19 - Yanaoca, Cusco, Peru             76
# 1        8217                 COVID-19 - Sicuani, Cusco, Peru             95
# 9        8218             COVID-19 - Santo Tomas, Cusco, Peru             99
# 32       8219                 COVID-19 - Acomayo, Cusco, Peru              2
# 5        8232                 COVID-19_Sri Lanka_Akurana area             75
# 31       8248                  COVID-19 - Ccatca, Cusco, Peru              0
# 30       8249                  COVID-19 - Ccorca, Cusco, Peru              0
# 0        8257             COVID-19 - Machupicchu, Cusco, Peru             21
#
#     percentValidated priority     status
# 39                 0      LOW  PUBLISHED
# 38                 3      LOW  PUBLISHED
# 29               100   MEDIUM  PUBLISHED
# 37                21      LOW  PUBLISHED
# 28                30   MEDIUM  PUBLISHED
# 36                53      LOW  PUBLISHED
# 4                 46   URGENT  PUBLISHED
# 27                 0   MEDIUM  PUBLISHED
# 35                54      LOW  PUBLISHED
# 26               100   MEDIUM  PUBLISHED
# 25                74   MEDIUM  PUBLISHED
# 34               100      LOW  PUBLISHED
# 24                51   MEDIUM  PUBLISHED
# 33                 9      LOW  PUBLISHED
# 8                  0     HIGH  PUBLISHED
# 7                  0     HIGH  PUBLISHED
# 23                 0   MEDIUM  PUBLISHED
# 22                 0   MEDIUM  PUBLISHED
# 21                 0   MEDIUM  PUBLISHED
# 20                 0   MEDIUM  PUBLISHED
# 19                 0   MEDIUM  PUBLISHED
# 18                 0   MEDIUM  PUBLISHED
# 17                 0   MEDIUM  PUBLISHED
# 16                 0   MEDIUM  PUBLISHED
# 15                 0   MEDIUM  PUBLISHED
# 14                 0   MEDIUM  PUBLISHED
# 13                 0   MEDIUM  PUBLISHED
# 12                 0   MEDIUM  PUBLISHED
# 11                 1   MEDIUM  PUBLISHED
# 10                 0   MEDIUM  PUBLISHED
# 3                 67   URGENT  PUBLISHED
# 2                 33   URGENT  PUBLISHED
# 6                 17     HIGH  PUBLISHED
# 1                 80   URGENT  PUBLISHED
# 9                 40   MEDIUM  PUBLISHED
# 32                 0      LOW  PUBLISHED
# 5                  7     HIGH  PUBLISHED
# 31                 0      LOW  PUBLISHED
# 30                 0      LOW  PUBLISHED
# 0                  0   URGENT  PUBLISHED

# %%
# prints the above pretty-printed data in plain CSV format 
from io import StringIO
csv = StringIO()
del res['shortDescription']
res.to_csv(csv, index=False)
print(csv.getvalue());
# Out:
# activeMappers,campaignTag,locale,mapperLevel,name,organisationTag,percentMapped,percentValidated,priority,projectId,status
# 6,COVID-19,en,BEGINNER,"COVID-19 - Machupicchu, Cusco, Peru",Gal School Peru,21,0,URGENT,8257,PUBLISHED
# 2,COVID-19,en,BEGINNER,"COVID-19 - Sicuani, Cusco, Peru",Gal School Peru,95,80,URGENT,8217,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Anta, Cusco, Peru",Gal School Peru,94,33,URGENT,8214,PUBLISHED
# 0,COVID-19,en,INTERMEDIATE,"COVID-19 - Urubamba, Cusco, Peru",Gal School Peru,85,67,URGENT,8213,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 San Jeronimo - Cusco , Peru",Gal School Peru,94,46,URGENT,7770,PUBLISHED
# 0,,en,INTERMEDIATE,COVID-19_Sri Lanka_Akurana area,UN Habitat,75,7,HIGH,8232,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Yanaoca, Cusco, Peru",Gal School Peru,76,17,HIGH,8216,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 2,GeolabUdea,25,0,HIGH,8189,PUBLISHED
# 1,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 1,GeolabUdea,59,0,HIGH,8188,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Santo Tomas, Cusco, Peru",Gal School Peru,99,40,MEDIUM,8218,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 15,GeolabUdea,42,0,MEDIUM,8203,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 16,GeolabUdea,40,1,MEDIUM,8202,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 14,GeolabUdea,28,0,MEDIUM,8201,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 13,GeolabUdea,2,0,MEDIUM,8200,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 12,GeolabUdea,3,0,MEDIUM,8199,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 11,GeolabUdea,18,0,MEDIUM,8198,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 10,GeolabUdea,12,0,MEDIUM,8197,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 9,GeolabUdea,5,0,MEDIUM,8196,PUBLISHED
# 1,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 8,GeolabUdea,2,0,MEDIUM,8195,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 7,GeolabUdea,13,0,MEDIUM,8194,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 6,GeolabUdea,4,0,MEDIUM,8193,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 5,GeolabUdea,17,0,MEDIUM,8192,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 4,GeolabUdea,1,0,MEDIUM,8191,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 3,GeolabUdea,15,0,MEDIUM,8190,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Omacha - Paruro, Peru",Gal School Peru,99,51,MEDIUM,8049,PUBLISHED
# 1,COVID-19,en,BEGINNER,"COVID-19 - Santa Teresa, La Convención, Peru",Gal School Peru,74,74,MEDIUM,8047,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Urcos - Quispicanchi, Peru",Gal School Peru,99,100,MEDIUM,7972,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Andahuaylillas - Quispicanchi, Peru",Gal School Peru,99,0,MEDIUM,7968,PUBLISHED
# 20,COVID-19,en,BEGINNER,"COVID-19 - Chamaca - Chumbivilcas, Peru",Gal School Peru,53,30,MEDIUM,7768,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Yaurisque District, Cusco - Peru",Gal School Peru,100,100,MEDIUM,7379,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Ccorca, Cusco, Peru",Gal School Peru,0,0,LOW,8249,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Ccatca, Cusco, Peru",Gal School Peru,0,0,LOW,8248,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Acomayo, Cusco, Peru",Gal School Peru,2,0,LOW,8219,PUBLISHED
# 1,,en,BEGINNER,Impendle,OSM Africa,26,9,LOW,8159,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Ccapi - Paruro, Peru",Gal School Peru,99,100,LOW,8048,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Lucre - Quispicanchi, Peru",Gal School Peru,92,54,LOW,7970,PUBLISHED
# 0,,en,BEGINNER,"COVID-19 - Saylla - Cusco , Peru",Gal School Peru,100,53,LOW,7769,PUBLISHED
# 1,COVID-19,en,BEGINNER,"COVID-19 - Coya - Calca, Peru",Gal School Peru,100,21,LOW,7721,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Paucartambo 1, Cusco, Peru",Gal School Peru,99,3,LOW,7372,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19, Quehue, Anna, Cusco Peru",Gal School Peru,98,0,LOW,5909,PUBLISHED
