# %% [markdown]
# This is a Jupyter notebook for quickly summarizing the status of a HOTOSM Tasking Manager campaing using the TM API.
# It uses the same search functionality as the keyword search o tasks.atotosm.org/contribute
#
# **Usage**:
#
# 1. Set your search keydword to `textSearch`
# 2. Execute all cells.
# 3. The results are sorted by project ID by default so the order stays consistent over time

# %%
# set the text search keyword
textSearch = 'COVID'
sort_by = 'projectId'

#################
import requests
import json
import pandas as pd

def getAllPages(textSearch):
    page = 1
    while True:
        r = requests.get(f'https://tasks.hotosm.org/api/v1/project/search?mapperLevel=ALL&textSearch={textSearch}&page={page}', 
            headers = {
                'Accept-Language': '*'
            }
        )
        j = json.loads(r.content)
        df = pd.DataFrame(json.loads(r.content)['results'])
        yield df
        if j['pagination']['hasNext'] is True:
            page = j['pagination']['nextNum']
        else:
            break

res = pd.concat(getAllPages(textSearch), ignore_index=True);

pd.set_option('display.max_rows', 500)
display(res[['projectId','name','percentMapped', 'percentValidated','priority','status']].sort_values(sort_by))
# Out:
#     projectId                                            name  percentMapped  \
# 37       5909              COVID-19, Quehue, Anna, Cusco Peru             98
# 36       7372           COVID-19 - Paucartambo 1, Cusco, Peru             99
# 29       7379       COVID-19 Yaurisque District, Cusco - Peru            100
# 35       7721                   COVID-19 - Coya - Calca, Peru            100
# 28       7768         COVID-19 - Chamaca - Chumbivilcas, Peru             43
# 34       7769                COVID-19 - Saylla - Cusco , Peru            100
# 3        7770            COVID-19 San Jeronimo - Cusco , Peru             94
# 27       7968  COVID-19 - Andahuaylillas - Quispicanchi, Peru             99
# 26       7969             COVID-19 Huaro - Quispicanchi, Peru             92
# 33       7970             COVID-19 Lucre - Quispicanchi, Peru             92
# 25       7972           COVID-19 - Urcos - Quispicanchi, Peru             99
# 24       8047    COVID-19 - Santa Teresa, La Convención, Peru             74
# 23       8049                  COVID-19 Omacha - Paruro, Peru             99
# 32       8159                                        Impendle             25
# 7        8188            Mapatón COVID-19 Medellín - Comuna 1             53
# 6        8189            Mapatón COVID-19 Medellín - Comuna 2             18
# 22       8190            Mapatón COVID-19 Medellín - Comuna 3             15
# 21       8191            Mapatón COVID-19 Medellín - Comuna 4              1
# 20       8192            Mapatón COVID-19 Medellín - Comuna 5             17
# 19       8193            Mapatón COVID-19 Medellín - Comuna 6              4
# 18       8194            Mapatón COVID-19 Medellín - Comuna 7             13
# 17       8195            Mapatón COVID-19 Medellín - Comuna 8              2
# 16       8196            Mapatón COVID-19 Medellín - Comuna 9              5
# 15       8197           Mapatón COVID-19 Medellín - Comuna 10             12
# 14       8198           Mapatón COVID-19 Medellín - Comuna 11             13
# 13       8199           Mapatón COVID-19 Medellín - Comuna 12              3
# 12       8200           Mapatón COVID-19 Medellín - Comuna 13              2
# 11       8201           Mapatón COVID-19 Medellín - Comuna 14             28
# 10       8202           Mapatón COVID-19 Medellín - Comuna 16             40
# 9        8203           Mapatón COVID-19 Medellín - Comuna 15             42
# 2        8213                COVID-19 - Urubamba, Cusco, Peru             23
# 1        8214                    COVID-19 - Anta, Cusco, Peru             87
# 5        8216                 COVID-19 - Yanaoca, Cusco, Peru             51
# 0        8217                 COVID-19 - Sicuani, Cusco, Peru             93
# 8        8218             COVID-19 - Santo Tomas, Cusco, Peru             99
# 31       8219                 COVID-19 - Acomayo, Cusco, Peru              0
# 4        8232                 COVID-19_Sri Lanka_Akurana area             58
# 30       8248                  COVID-19 - Ccatca, Cusco, Peru              0
#
#     percentValidated priority     status
# 37                 0      LOW  PUBLISHED
# 36                 3      LOW  PUBLISHED
# 29               100   MEDIUM  PUBLISHED
# 35                 5      LOW  PUBLISHED
# 28                12   MEDIUM  PUBLISHED
# 34                34      LOW  PUBLISHED
# 3                 36   URGENT  PUBLISHED
# 27                 0   MEDIUM  PUBLISHED
# 26                97   MEDIUM  PUBLISHED
# 33                54      LOW  PUBLISHED
# 25               100   MEDIUM  PUBLISHED
# 24                74   MEDIUM  PUBLISHED
# 23                51   MEDIUM  PUBLISHED
# 32                 9      LOW  PUBLISHED
# 7                  0     HIGH  PUBLISHED
# 6                  0     HIGH  PUBLISHED
# 22                 0   MEDIUM  PUBLISHED
# 21                 0   MEDIUM  PUBLISHED
# 20                 0   MEDIUM  PUBLISHED
# 19                 0   MEDIUM  PUBLISHED
# 18                 0   MEDIUM  PUBLISHED
# 17                 0   MEDIUM  PUBLISHED
# 16                 0   MEDIUM  PUBLISHED
# 15                 0   MEDIUM  PUBLISHED
# 14                 0   MEDIUM  PUBLISHED
# 13                 0   MEDIUM  PUBLISHED
# 12                 0   MEDIUM  PUBLISHED
# 11                 0   MEDIUM  PUBLISHED
# 10                 0   MEDIUM  PUBLISHED
# 9                  0   MEDIUM  PUBLISHED
# 2                  0   URGENT  PUBLISHED
# 1                 19   URGENT  PUBLISHED
# 5                 17     HIGH  PUBLISHED
# 0                 79   URGENT  PUBLISHED
# 8                 40   MEDIUM  PUBLISHED
# 31                 0      LOW  PUBLISHED
# 4                  6     HIGH  PUBLISHED
# 30                 0      LOW  PUBLISHED

# %%
# prints the above pretty-printed data in plain CSV format 
from io import StringIO
csv = StringIO()
del res['shortDescription']
res.to_csv(csv, index=False)
print(csv.getvalue());
# Out:
# activeMappers,campaignTag,locale,mapperLevel,name,organisationTag,percentMapped,percentValidated,priority,projectId,status
# 11,COVID-19,en,BEGINNER,"COVID-19 - Sicuani, Cusco, Peru",Gal School Peru,93,79,URGENT,8217,PUBLISHED
# 3,COVID-19,en,BEGINNER,"COVID-19 - Anta, Cusco, Peru",Gal School Peru,87,19,URGENT,8214,PUBLISHED
# 3,COVID-19,en,INTERMEDIATE,"COVID-19 - Urubamba, Cusco, Peru",Gal School Peru,23,0,URGENT,8213,PUBLISHED
# 4,COVID-19,en,BEGINNER,"COVID-19 San Jeronimo - Cusco , Peru",Gal School Peru,94,36,URGENT,7770,PUBLISHED
# 0,,en,INTERMEDIATE,COVID-19_Sri Lanka_Akurana area,UN Habitat,58,6,HIGH,8232,PUBLISHED
# 5,COVID-19,en,BEGINNER,"COVID-19 - Yanaoca, Cusco, Peru",Gal School Peru,51,17,HIGH,8216,PUBLISHED
# 2,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 2,GeolabUdea,18,0,HIGH,8189,PUBLISHED
# 1,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 1,GeolabUdea,53,0,HIGH,8188,PUBLISHED
# 1,COVID-19,en,BEGINNER,"COVID-19 - Santo Tomas, Cusco, Peru",Gal School Peru,99,40,MEDIUM,8218,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 15,GeolabUdea,42,0,MEDIUM,8203,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 16,GeolabUdea,40,0,MEDIUM,8202,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 14,GeolabUdea,28,0,MEDIUM,8201,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 13,GeolabUdea,2,0,MEDIUM,8200,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 12,GeolabUdea,3,0,MEDIUM,8199,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 11,GeolabUdea,13,0,MEDIUM,8198,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 10,GeolabUdea,12,0,MEDIUM,8197,PUBLISHED
# 0,,es,BEGINNER,Mapatón COVID-19 Medellín - Comuna 9,GeolabUdea,5,0,MEDIUM,8196,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 8,GeolabUdea,2,0,MEDIUM,8195,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 7,GeolabUdea,13,0,MEDIUM,8194,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 6,GeolabUdea,4,0,MEDIUM,8193,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 5,GeolabUdea,17,0,MEDIUM,8192,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 4,GeolabUdea,1,0,MEDIUM,8191,PUBLISHED
# 0,,en,BEGINNER,Mapatón COVID-19 Medellín - Comuna 3,GeolabUdea,15,0,MEDIUM,8190,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Omacha - Paruro, Peru",Gal School Peru,99,51,MEDIUM,8049,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Santa Teresa, La Convención, Peru",Gal School Peru,74,74,MEDIUM,8047,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Urcos - Quispicanchi, Peru",Gal School Peru,99,100,MEDIUM,7972,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Huaro - Quispicanchi, Peru",Gal School Peru,92,97,MEDIUM,7969,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Andahuaylillas - Quispicanchi, Peru",Gal School Peru,99,0,MEDIUM,7968,PUBLISHED
# 4,COVID-19,en,BEGINNER,"COVID-19 - Chamaca - Chumbivilcas, Peru",Gal School Peru,43,12,MEDIUM,7768,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Yaurisque District, Cusco - Peru",Gal School Peru,100,100,MEDIUM,7379,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Ccatca, Cusco, Peru",Gal School Peru,0,0,LOW,8248,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Acomayo, Cusco, Peru",Gal School Peru,0,0,LOW,8219,PUBLISHED
# 0,,en,BEGINNER,Impendle,OSM Africa,25,9,LOW,8159,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 Lucre - Quispicanchi, Peru",Gal School Peru,92,54,LOW,7970,PUBLISHED
# 1,,en,BEGINNER,"COVID-19 - Saylla - Cusco , Peru",Gal School Peru,100,34,LOW,7769,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Coya - Calca, Peru",Gal School Peru,100,5,LOW,7721,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19 - Paucartambo 1, Cusco, Peru",Gal School Peru,99,3,LOW,7372,PUBLISHED
# 0,COVID-19,en,BEGINNER,"COVID-19, Quehue, Anna, Cusco Peru",Gal School Peru,98,0,LOW,5909,PUBLISHED
