# %%
# set the text search keyword
textSearch = 'covid'
instance = 'tasking-manager-staging-api.hotosm.org'

# %% [markdown]
# _query cell hidden for brevity_

# %%
import requests
import json
import pandas as pd

def getAllPages(textSearch):
    page = 1
    while True:
        r = requests.get(f'https://{instance}/api/v2/projects/?textSearch={textSearch}&page={page}', 
            headers = {
                'Accept-Language': '*',
                'Content-Type': 'application/json'
            }
        )
        j = json.loads(r.content)
        
        df = pd.DataFrame(json.loads(r.content)['results'])
        yield df
        if j['pagination']['hasNext'] is True:
            page = j['pagination']['nextNum']
        else:
            break

            
result = pd.concat(getAllPages(textSearch), ignore_index=True);
result['country'] = result['country'].apply(lambda x: x[0])  # country string is wrapped in an array

# %%
print(list(result.columns))
# Out:
# ['activeMappers', 'campaign', 'country', 'dueDate', 'lastUpdated', 'locale', 'mapperLevel', 'name', 'organisationLogo', 'organisationName', 'percentMapped', 'percentValidated', 'priority', 'projectId', 'shortDescription', 'status', 'totalContributors']

# %% [markdown]
# ## Total project count

# %%
print(len(result))
# Out:
# 46

# %% [markdown]
# # Currently published projects
#
# Drafts and archived project requires PM auth token.
#
# Sorted by country, then project Id

# %%
hotosm_colors = {
  "red": "#D73F3F",
  "red-dark": "#6C2020",
  "red-light": "#FFEDED",
  "orange": "#FAA71E",
  "tan": "#F0EFEF",
  "blue-dark": "#2C3038",
  "blue-grey": "#68707F",
  "blue-light": "#929DB3",
  "grey-light": "#E1E0E0",
  "green": "#53AE62"
  }

from matplotlib.colors import LinearSegmentedColormap

alpha = 0.7
colors = [(1,0,0,alpha),(1, 0.6, 0, alpha),(1,1,0,alpha),(0,0.7,0, alpha)]
colors = [hotosm_colors['red'],hotosm_colors['orange'],hotosm_colors['green']]
n_bin = [30, 60, 80, 100]
cm = LinearSegmentedColormap.from_list(
        'RgOrYlGn', colors, N=20)

def highlight_done(val):

    if val > 99.9:
        return 'background-color: "blue"'
    return ''

def highlight_priority(val):
    lookup = {
        'LOW': hotosm_colors['grey-light'],
        'MEDIUM': hotosm_colors['green'],
        'HIGH': hotosm_colors['orange'],
        'URGENT': hotosm_colors['red']
    }
    color = lookup[val]
    return f'background-color: {color}'


relevant = result[['projectId','name','percentMapped', 'percentValidated','priority','status','campaign','country', 'totalContributors']]
pd.set_option('display.max_rows', 500)
sorted_vals = relevant.sort_values(['country','projectId'])
styled = sorted_vals.style\
    .applymap(highlight_done, subset=['percentMapped', 'percentValidated'])\
    .background_gradient(cmap=cm,subset=['percentMapped', 'percentValidated'])\
    .applymap(highlight_priority, subset=['priority'])
    
styled
# Out:
# <style  type="text/css" >
#     #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow0_col2 {
#             : ;
#             background-color:  #bcaa37;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow0_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow0_col4 {
#             background-color:  #FAA71E;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow1_col2 {
#             : ;
#             background-color:  #99ab45;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow1_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow1_col4 {
#             background-color:  #FAA71E;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow2_col2 {
#             : ;
#             background-color:  #e26035;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow2_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow2_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow3_col2 {
#             : ;
#             background-color:  #e26035;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow3_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow3_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow4_col2 {
#             : ;
#             background-color:  #db4a3c;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow4_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow4_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow5_col2 {
#             : ;
#             background-color:  #db4a3c;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow5_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow5_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow6_col2 {
#             : ;
#             background-color:  #e26035;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow6_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow6_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow7_col2 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow7_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow7_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow8_col2 {
#             : ;
#             background-color:  #f49723;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow8_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow8_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow9_col2 {
#             : ;
#             background-color:  #f49723;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow9_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow9_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow10_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow10_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow10_col4 {
#             background-color:  #E1E0E0;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow11_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow11_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow11_col4 {
#             background-color:  #E1E0E0;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow12_col2 {
#             background-color:  "blue";
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow12_col3 {
#             background-color:  "blue";
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow12_col4 {
#             background-color:  #E1E0E0;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow13_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow13_col3 {
#             : ;
#             background-color:  #cea930;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow13_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow14_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow14_col3 {
#             : ;
#             background-color:  #cea930;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow14_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow15_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow15_col3 {
#             : ;
#             background-color:  #cea930;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow15_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow16_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow16_col3 {
#             : ;
#             background-color:  #cea930;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow16_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow17_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow17_col3 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow17_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow18_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow18_col3 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow18_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow19_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow19_col3 {
#             : ;
#             background-color:  #e0a829;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow19_col4 {
#             background-color:  #E1E0E0;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow20_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow20_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow20_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow21_col2 {
#             : ;
#             background-color:  #53ae62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow21_col3 {
#             : ;
#             background-color:  #d73f3f;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow21_col4 {
#             background-color:  #53AE62;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow22_col2 {
#             : ;
#             background-color:  #65ad5b;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow22_col3 {
#             : ;
#             background-color:  #cea930;
#         }    #T_0cf1b3fe_8088_11ea_a866_c5e32d5c1a3erow22_col4 {
#             background-col
