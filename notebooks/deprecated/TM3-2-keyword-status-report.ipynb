# %% [markdown]
# This is a Jupyter notebook for quickly summarizing the status of a HOTOSM Tasking Manager campaing using the TM API.
# It uses the same search functionality as the keyword search on tasks.hotosm.org/contribute
#
# **Usage**:
#
# 1. Set your search keydword to `textSearch`
# 2. Execute all cells.
# 3. The results are sorted by project ID by default so the order stays consistent over time (bottom of the notebook)

# %%
# set the text search keyword
textSearch = 'covid'
instance = 'tasks.hotosm.org'

# %%
import requests
import json
import pandas as pd

# make sure pandas doesn't truncate the dataframe when rendered
pd.set_option('display.max_rows', 500)

def getAllPages(textSearch):
    page = 1
    while True:
        r = requests.get(f'https://tasks.hotosm.org/api/v1/project/search?textSearch={textSearch}&page={page}', 
            headers = {
                'Accept-Language': '*',
                'Content-Type': 'application/json'
            }
        )
        j = json.loads(r.content)
        df = pd.DataFrame(json.loads(r.content)['results'])
        yield df
        if j['pagination']['hasNext'] is True:
            page = j['pagination']['nextNum']
        else:
            break

            
# concatenate paginated API results into one dataframe
result = pd.concat(getAllPages(textSearch), ignore_index=True);
# search API pagination sometimes returns the same project more than once
result = result.drop_duplicates(subset='projectId');

# %%
# list of all fields for reference, for the sake
# of readability, some are not included in the final
# rendered table
print(list(result.columns))
# Out:
# ['activeMappers', 'campaignTag', 'locale', 'mapperLevel', 'name', 'organisationTag', 'percentMapped', 'percentValidated', 'priority', 'projectId', 'shortDescription', 'status']

# %% [markdown]
# # Currently published projects
#
# Drafts and archived project requires PM auth token.
#
# Sorted by country, then project Id

# %%
# this cells applyies some sematic style to make the
# search summary nicer to read
from matplotlib.colors import LinearSegmentedColormap
from datetime import datetime

# colors from the HOTOSM media kit :)
hotosm_colors = {
  "red": "#D73F3F",
  "red-dark": "#6C2020",
  "red-light": "#FFEDED",
  "orange": "#FAA71E",
  "tan": "#F0EFEF",
  "blue-dark": "#2C3038",
  "blue-grey": "#68707F",
  "blue-light": "#929DB3",
  "grey-light": "#E1E0E0",
  "green": "#53AE62"
  }

# create a colormap for colorign mappedness and validatedness percentages
colors = [hotosm_colors['red'],hotosm_colors['orange'],hotosm_colors['green']]
colormap = LinearSegmentedColormap.from_list('hotosm-RdOrGr', colors, N=20)

# Pandas dataframe render styler functions
def highlight_priority(val):
    """set cell color based on proejct priority in TM"""
    lookup = {
        'LOW': hotosm_colors['grey-light'],
        'MEDIUM': hotosm_colors['green'],
        'HIGH': hotosm_colors['orange'],
        'URGENT': hotosm_colors['red']
    }
    color = lookup[val]
    return f'background-color: {color}'


# for notebooks used for reporting, it's nice to
# timestamp of the data, since it can get old quickly
now = datetime.utcnow()
print(f'last updated: {now} UTC')
# Total count of projects
print(f'total number of published projects: {len(result)}')

# We select only the most interesting fields from the dataframe
relevant = result[['projectId','name','percentMapped', 'percentValidated','priority','status', 'campaignTag']]
# Sorting by project id is somewhat cronological
# and also keeps the table order intact as new project are created
sorted_vals = relevant.sort_values('projectId')

# apply custom styler functions to final table
styled = sorted_vals.style\
    .background_gradient(cmap=colormap,subset=['percentMapped', 'percentValidated'])\
    .applymap(highlight_priority, subset=['priority'])

display(styled)
# Out:
# last updated: 2020-04-17 16:56:39.505670 UTC
# total number of published projects: 56
# <style  type="text/css" >
#     #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow0_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow0_col3 {
#             background-color:  #e9762e;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow0_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow1_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow1_col3 {
#             background-color:  #db4a3c;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow1_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow2_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow2_col3 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow2_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow3_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow3_col3 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow3_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow4_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow4_col3 {
#             background-color:  #e0a829;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow4_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow5_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow5_col3 {
#             background-color:  #e0a829;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow5_col4 {
#             background-color:  #FAA71E;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow6_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow6_col3 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow6_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow7_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow7_col3 {
#             background-color:  #e0a829;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow7_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow8_col2 {
#             background-color:  #88ac4d;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow8_col3 {
#             background-color:  #e66b31;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow8_col4 {
#             background-color:  #E1E0E0;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow9_col2 {
#             background-color:  #65ad5b;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow9_col3 {
#             background-color:  #db4a3c;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow9_col4 {
#             background-color:  #D73F3F;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow10_col2 {
#             background-color:  #53ae62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow10_col3 {
#             background-color:  #e9762e;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow10_col4 {
#             background-color:  #FAA71E;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow11_col2 {
#             background-color:  #e26035;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow11_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow11_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow12_col2 {
#             background-color:  #db4a3c;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow12_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow12_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow13_col2 {
#             background-color:  #e66b31;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow13_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow13_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow14_col2 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow14_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow14_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow15_col2 {
#             background-color:  #e9762e;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow15_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow15_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow16_col2 {
#             background-color:  #db4a3c;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow16_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow16_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow17_col2 {
#             background-color:  #de5538;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow17_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow17_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow18_col2 {
#             background-color:  #de5538;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow18_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow18_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow19_col2 {
#             background-color:  #f49723;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow19_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow19_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow20_col2 {
#             background-color:  #88ac4d;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow20_col3 {
#             background-color:  #88ac4d;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow20_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow21_col2 {
#             background-color:  #99ab45;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow21_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow21_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow22_col2 {
#             background-color:  #e9762e;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow22_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow22_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow23_col2 {
#             background-color:  #f49723;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow23_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow23_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow24_col2 {
#             background-color:  #f8a220;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow24_col3 {
#             background-color:  #d73f3f;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow24_col4 {
#             background-color:  #53AE62;
#         }    #T_68126ac8_80cc_11ea_a866_c5e32d5c1a3erow25_col2 {
#             background-color:  #65ad5b;
#         }    #T_68126ac8_80cc_11e
